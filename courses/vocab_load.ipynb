# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://gre.economist.com/gre-advice/gre-vocabulary/which-words-study/most-common-gre-vocabulary-list-organized-difficulty").content.decode()

# %%
page
# Out:
# '<!doctype html><!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang=""> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9" lang=""> <![endif]--><!--[if gt IE 8]><!--><html class=no-js><!--<![endif]--><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge,chrome=1"><meta name=viewport content="width=device-width,initial-scale=1"><title>Most common GRE vocabulary: A list organized by difficulty</title><meta property=og:title content="Most common GRE vocabulary: A list organized by difficulty"><meta name=twitter:title content="Most common GRE vocabulary: A list organized by difficulty"><meta name=description content="For many GRE test-takers, vocabulary-building presents a special challenge."><meta property=og:description content="For many GRE test-takers, vocabulary-building presents a special challenge."><meta name=twitter:description content="For many GRE test-take
# ...

# %%
# lmao find the hard vocab

page = page.split("Most Difficult")[1]

# %%
page
# Out:
# '</h2><p><a href=https://gre.economist.com/gre-vocabulary/abeyance/2017-01-11>Abeyance</a>: noun, a state of temporary disuse or suspension<br>Synonyms: suspense, remission, reserve<br>“With the euro crisis in&nbsp;<a href=https://gre.economist.com/gre-vocabulary/abeyance/2017-01-11>abeyance</a>, high oil prices have become the latest source of worry for the world economy.”<br><em>Source: "The new grease?" published in The Economist</em><p><a href=https://gre.economist.com/gre-vocabulary/abjure/2016-12-12>Abjure</a>: verb, Solemnly renounce (a belief, cause, or claim)<br>Synonyms: relinquish, reject, disavow<br>“Since 1986 he has been asking candidates for public office to sign his Taxpayer Protection Pledge, in which they&nbsp;<a href=https://gre.economist.com/gre-vocabulary/abjure/2016-12-12>abjure</a>&nbsp;tax increases of any sort forever.”<br><em>Source: "It’s not over for Grover" published in The Economist</em><p><a href="https://gre.economist.com/gre-vocabulary/%3Ca%20href=">a
# ...

# %%
a = page.split("</a")
b= list(set([c.split(">")[-1].lower() for c in a][:186]))
b
# Out:
# ['iconoclast',
#  'occlude',
#  'prosaic',
#  'abjure',
#  'halcyon',
#  'polemic',
#  'myopic',
#  'welter',
#  'fusillade',
#  'heterodox',
#  'quiescence',
#  'xenophobia',
#  'yoke',
#  'frieze',
#  'libertine',
#  'ignoble',
#  'diatribe',
#  'egress',
#  'turgid',
#  'supine',
#  'vociferous',
#  'ambivalent',
#  'erstwhile',
#  'edify',
#  'mal',
#  'sobriquet',
#  'incise',
#  'paucity',
#  'abeyance',
#  'anodyne',
#  'gainsay',
#  'savant',
#  'précis',
#  'cloture',
#  'homogeneous',
#  'verdant',
#  'indolence',
#  'slight',
#  'euphony',
#  'extol',
#  'hegemony',
#  'ersatz',
#  'diurnal',
#  'nadir',
#  'soporific',
#  'daguerreotype',
#  'gaffe',
#  'compendium',
#  'nostrum',
#  'dyspeptic',
#  'pastiche',
#  'catalyst',
#  'panoply',
#  'magnate',
#  'enlist',
#  'conscript',
#  'catharsis',
#  'philistine',
#  'repast',
#  'vitiate',
#  'waft',
#  'expiate',
#  'neophyte',
#  'boor',
#  'munificent',
#  'paean',
#  'maelstrom',
#  'bilk',
#  'truculent',
# ...

# %%
with open("./vocab.txt", 'w') as outfile:
    for word in b:
        outfile.write(word + "\n")
